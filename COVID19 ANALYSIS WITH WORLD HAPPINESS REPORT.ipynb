# %% [markdown]
# <b><center>COVID19 DATA ANALYSIS WITH WORLD HAPPINESS REPORT</center><b>

# %% [markdown]
# <h2>Task I
# <h2>Importing python packets and dataset for analysis</h2></style>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# <h3>Importing COVID-19 dataset</h3>
# <br>
# - The dataset is published by <b>John Hopkins University</b><br>
# - It is from <b>from Jan 22,2020 to June 8,2020</b>

# %%
covid_data = pd.read_csv("covid19_Confirmed_dataset.csv.")
covid_data.head(10)
# Out:
#                  Province/State       Country/Region      Lat      Long  \
# 0                           NaN          Afghanistan  33.0000   65.0000
# 1                           NaN              Albania  41.1533   20.1683
# 2                           NaN              Algeria  28.0339    1.6596
# 3                           NaN              Andorra  42.5063    1.5218
# 4                           NaN               Angola -11.2027   17.8739
# 5                           NaN  Antigua and Barbuda  17.0608  -61.7964
# 6                           NaN            Argentina -38.4161  -63.6167
# 7                           NaN              Armenia  40.0691   45.0382
# 8  Australian Capital Territory            Australia -35.4735  149.0124
# 9               New South Wales            Australia -33.8688  151.2093
#
#    1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20   ...     4/21/20  \
# 0        0        0        0        0        0        0   ...        1092
# ...

# %%
happ_report = pd.read_csv("worldwide_happiness_report.csv")
happ_report.head(10)
# Out:
#    Overall rank Country or region  Score  GDP per capita  Social support  \
# 0             1           Finland  7.769           1.340           1.587
# 1             2           Denmark  7.600           1.383           1.573
# 2             3            Norway  7.554           1.488           1.582
# 3             4           Iceland  7.494           1.380           1.624
# 4             5       Netherlands  7.488           1.396           1.522
# 5             6       Switzerland  7.480           1.452           1.526
# 6             7            Sweden  7.343           1.387           1.487
# 7             8       New Zealand  7.307           1.303           1.557
# 8             9            Canada  7.278           1.365           1.505
# 9            10           Austria  7.246           1.376           1.475
#
#    Healthy life expectancy  Freedom to make life choices  Generosity  \
# 0                    0.986                         0.596       0.153
# ...

# %% [markdown]
# ## Task II
# ## Study the covid data for analysis

# %%
display(covid_data)
# Out:
#                        Province/State          Country/Region        Lat  \
# 0                                 NaN             Afghanistan  33.000000
# 1                                 NaN                 Albania  41.153300
# 2                                 NaN                 Algeria  28.033900
# 3                                 NaN                 Andorra  42.506300
# 4                                 NaN                  Angola -11.202700
# 5                                 NaN     Antigua and Barbuda  17.060800
# 6                                 NaN               Argentina -38.416100
# 7                                 NaN                 Armenia  40.069100
# 8        Australian Capital Territory               Australia -35.473500
# 9                     New South Wales               Australia -33.868800
# 10                 Northern Territory               Australia -12.463400
# 11                         Queensland               Australia -28.016700
# ...

# %%
covid_data.shape
# Out:
# (266, 104)

# %% [markdown]
# <br>--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## Task II
# ## Pre-Processing Data
#
# <h3><u>Note:</u>
# <h4>There exist some columns in the dataset with no use for analysis like index,latitude,longitude. Hence, dropping that olumns would make it easy for analysis.

# %%
covid_data.columns
# Out:
# Index(['Province/State', 'Country/Region', 'Lat', 'Long', '1/22/20', '1/23/20',
#        '1/24/20', '1/25/20', '1/26/20', '1/27/20',
#        ...
#        '4/21/20', '4/22/20', '4/23/20', '4/24/20', '4/25/20', '4/26/20',
#        '4/27/20', '4/28/20', '4/29/20', '4/30/20'],
#       dtype='object', length=104)

# %% [markdown]
# ### Dropping the Latitude and Logitude columns

# %%
covid_data.drop(["Lat", "Long"],axis=1,inplace=True)

# %%
covid_data.head()
# Out:
#   Province/State Country/Region  1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  \
# 0            NaN    Afghanistan        0        0        0        0        0
# 1            NaN        Albania        0        0        0        0        0
# 2            NaN        Algeria        0        0        0        0        0
# 3            NaN        Andorra        0        0        0        0        0
# 4            NaN         Angola        0        0        0        0        0
#
#    1/27/20  1/28/20  1/29/20   ...     4/21/20  4/22/20  4/23/20  4/24/20  \
# 0        0        0        0   ...        1092     1176     1279     1351
# 1        0        0        0   ...         609      634      663      678
# 2        0        0        0   ...        2811     2910     3007     3127
# 3        0        0        0   ...         717      723      723      731
# 4        0        0        0   ...          24       25       25       25
#
#    4/25/20  4/26/20  4/27/20  4/28/20  4/29/20  4/30/20
# ...

# %%
covid_data.shape
# Out:
# (266, 102)

# %% [markdown]
# <br>--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ### To find is there any null data`

# %%
### In the way of plotting using seaborn

plt.figure(figsize=(12,8))
sns.heatmap(covid_data.isnull(),yticklabels=False)

# %%
## For better understanding of null data

covid_data.isnull().sum()
# Out:
# Province/State    184
# Country/Region      0
# 1/22/20             0
# 1/23/20             0
# 1/24/20             0
# 1/25/20             0
# 1/26/20             0
# 1/27/20             0
# 1/28/20             0
# 1/29/20             0
# 1/30/20             0
# 1/31/20             0
# 2/1/20              0
# 2/2/20              0
# 2/3/20              0
# 2/4/20              0
# 2/5/20              0
# 2/6/20              0
# 2/7/20              0
# 2/8/20              0
# 2/9/20              0
# 2/10/20             0
# 2/11/20             0
# 2/12/20             0
# 2/13/20             0
# 2/14/20             0
# 2/15/20             0
# 2/16/20             0
# 2/17/20             0
# 2/18/20             0
#                  ...
# 4/1/20              0
# 4/2/20              0
# 4/3/20              0
# 4/4/20              0
# 4/5/20              0
# 4/6/20              0
# 4/7/20              0
# 4/8/20              0
# 4/9/20              0
# 4/10/20             0
# ...

# %% [markdown]
# <h4>States that there are 184 null data in Province/State column

# %% [markdown]
# #### Here,  Province/State is nothing but where the country belongs to. It woulb me more meaningful when we analyze with countries and province/state is not really needed!!

# %% [markdown]
# <br>--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## Task IV
# ## Aggregating or grouping by Country

# %%
covid_data_agg = covid_data.groupby("Country/Region").sum()

# %%
covid_data_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20   ...     4/21/20  4/22/20  4/23/20  \
# Country/Region                              ...
# Afghanistan           0        0        0   ...        1092     1176     1279
# Albania               0        0        0   ...         609      634      663
# Algeria               0        0        0   ...        2811     2910     3007
# Andorra               0        0        0   ...         717      723      723
# ...

# %%
covid_data_agg.shape
# Out:
# (187, 100)

# %% [markdown]
# <br>--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ## Task V
# ## Visualization of how covid affects each countries

# %%
covid_data_agg.loc["China"].plot()

# %%
plt.figure(figsize=(10,8))
covid_data_agg.loc["China"].plot()
covid_data_agg.loc["India"].plot()
covid_data_agg.loc["United Kingdom"].plot()
plt.legend()
plt.title("Cases found in China | India | United Kingdom")
plt.xlabel("Date")
plt.ylabel("People Affected")
# Out:
# Text(0, 0.5, 'People Affected')

# %% [markdown]
# #### Considering only France

# %%
### Let's take France and try to understand better

covid_data_agg.loc["France"].plot()

# %%
plt.figure(figsize=(10,8))
plt.title("Plot for Number of cases found in very first 100 days")
plt.ylabel("Nuber of Cases")
plt.xlabel("Dates")
covid_data_agg.loc["France"][:100].plot(figsize=(8,4))

# %% [markdown]
# ### Plotting the first derivative of the curve
# #### Let us find the maximum rate at which covid hit the coutry/region

# %%
covid_data_agg.loc["France"].diff().plot(figsize=(8,4))
plt.legend()
plt.ylabel("Nuber of Cases")
plt.xlabel("Dates")
# Out:
# Text(0.5, 0, 'Dates')

# %% [markdown]
# <b>Maximum number of infected cases in One day</b>

# %%
print("France - ",covid_data_agg.loc["France"].diff().max())
# Out:
# France -  26849.0

# %% [markdown]
# #### States that more than 26849 cases hit in France

# %%
### Let us take some countries for sample

print("China -",covid_data_agg.loc["China"].diff().max())
print("Italy -",covid_data_agg.loc["Italy"].diff().max())
print("UK -",covid_data_agg.loc["United Kingdom"].diff().max())
print("US -",covid_data_agg.loc["US"].diff().max())
# Out:
# China - 15136.0
# Italy - 6557.0
# UK - 8733.0
# US - 36188.0

# %% [markdown]
# ## Maximum Rate of Case for all countries

# %%
countries = list(covid_data_agg.index)
max_infections = []
for i in countries:
    max_infections.append(covid_data_agg.loc[i].diff().max())
covid_data_agg["max_infections"] = max_infections 
covid_data_agg.head()
# Out:
#                 1/22/20  1/23/20  1/24/20  1/25/20  1/26/20  1/27/20  1/28/20  \
# Country/Region
# Afghanistan           0        0        0        0        0        0        0
# Albania               0        0        0        0        0        0        0
# Algeria               0        0        0        0        0        0        0
# Andorra               0        0        0        0        0        0        0
# Angola                0        0        0        0        0        0        0
#
#                 1/29/20  1/30/20  1/31/20       ...        4/22/20  4/23/20  \
# Country/Region                                  ...
# Afghanistan           0        0        0       ...           1176     1279
# Albania               0        0        0       ...            634      663
# Algeria               0        0        0       ...           2910     3007
# Andorra               0        0        0       ...            723      723
# ...

# %% [markdown]
# #### Creating a column called "max_infections" which shows the maximum number of infections per day in each country

# %% [markdown]
# <br>--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------
# ### Considering only the necessary "max_infections" column

# %%
corona_infection = pd.DataFrame(covid_data_agg["max_infections"])
corona_infection.head()
# Out:
#                 max_infections
# Country/Region
# Afghanistan              232.0
# Albania                   34.0
# Algeria                  199.0
# Andorra                   43.0
# Angola                     5.0

# %% [markdown]
# ## Task VI
# ### Studying World Happiness dataset

# %%
display(happ_report)
# Out:
#      Overall rank         Country or region  Score  GDP per capita  \
# 0               1                   Finland  7.769           1.340
# 1               2                   Denmark  7.600           1.383
# 2               3                    Norway  7.554           1.488
# 3               4                   Iceland  7.494           1.380
# 4               5               Netherlands  7.488           1.396
# 5               6               Switzerland  7.480           1.452
# 6               7                    Sweden  7.343           1.387
# 7               8               New Zealand  7.307           1.303
# 8               9                    Canada  7.278           1.365
# 9              10                   Austria  7.246           1.376
# 10             11                 Australia  7.228           1.372
# 11             12                Costa Rica  7.167           1.034
# 12             13                    Israel  7.139           1.276
# ...

# %%
happ_report.shape
# Out:
# (156, 9)

# %% [markdown]
# ### Dropping unnecessary columns

# %%
happ_report.drop(["Score","Perceptions of corruption","Generosity"], axis = 1,inplace = True)

# %% [markdown]
# #### These columns will never give any useful insights for the prediction

# %% [markdown]
# <br>------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Task VII
# ### Merging the datasets
# <p>Setting the index as "Country/Region" in order to join both the datasets based on that column</b>

# %%
happ_report.rename(columns = {"Country or region":"Country/Region"},inplace = True)

# %%
happ_report.set_index("Country/Region",inplace=True)

# %%
print(corona_infection.shape)
print(happ_report.shape)
# Out:
# (187, 1)
# (156, 5)

# %% [markdown]
# <b>Note : <br>Since the shape is dissimilar join by using inner join

# %%
df = corona_infection.join(happ_report,how="inner")
df.head()
# Out:
#                 max_infections  Overall rank  GDP per capita  Social support  \
# Country/Region
# Afghanistan              232.0           154           0.350           0.517
# Albania                   34.0           107           0.947           0.848
# Algeria                  199.0            88           1.002           1.160
# Argentina                291.0            47           1.092           1.432
# Armenia                  134.0           116           0.850           1.055
#
#                 Healthy life expectancy  Freedom to make life choices
# Country/Region
# Afghanistan                       0.361                         0.000
# Albania                           0.874                         0.383
# Algeria                           0.785                         0.086
# Argentina                         0.881                         0.471
# Armenia                           0.815                         0.283

# %% [markdown]
# ### Correlation of dataset

# %%
df.corr()
# Out:
#                               max_infections  Overall rank  GDP per capita  \
# max_infections                      1.000000     -0.244777        0.250118
# Overall rank                       -0.244777      1.000000       -0.802204
# GDP per capita                      0.250118     -0.802204        1.000000
# Social support                      0.191958     -0.780955        0.759468
# Healthy life expectancy             0.289263     -0.804753        0.863062
# Freedom to make life choices        0.078196     -0.570490        0.394603
#
#                               Social support  Healthy life expectancy  \
# max_infections                      0.191958                 0.289263
# Overall rank                       -0.780955                -0.804753
# GDP per capita                      0.759468                 0.863062
# Social support                      1.000000                 0.765286
# Healthy life expectancy             0.765286                 1.000000
# ...

# %%
## For better understanding - visualizing the correlation
f,ax = plt.subplots(figsize = (8,5))
sns.heatmap(df.corr(),annot = True,fmt='.2f',linewidths=.3,ax=ax)

# %% [markdown]
# <b>GDP per capita vs max_infections</b>

# %%
x=df["GDP per capita"]
y=df["max_infections"]
sns.regplot(x,np.log(y),data=df)

# %% [markdown]
# <b>Social support vs max_infections

# %%
x=df["Social support"]
y=df["max_infections"]
sns.regplot(x,np.log(y))

# %% [markdown]
# <b>Freedom to make life choices vs max_infections

# %%
x=df["Freedom to make life choices"]
y=df["max_infections"]
sns.regplot(x,np.log(y))

# %%
x=df["Overall rank"]
y=df["max_infections"]
sns.regplot(x,np.log(y))

# %% [markdown]
# ### Result

# %% [markdown]
# - It is found that the <b>OVERALL RANK and MAXIMUM INFECTIONS ARE INVERSELY PROPORTIONAL</b>
#    - (i.e) - <b>maximum number</b> of COVID-19 infections are in the <b>most DEVELOPED COUNTRIES compared to LESS DEVELOPED and DEVELOPING COUNTRIES.</b>
#
#
# - It may be <b>due to the factors such as
#     - less people being tested in the developing countries in comparison to the developed countries
#     - lack of kits available in developing countries.</b>
#
#  - This can be verified by using the cumulative death rate of each countries
